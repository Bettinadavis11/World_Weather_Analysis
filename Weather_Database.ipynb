# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Create list for holding the cities
cities = []

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city is unique, add to cities list
    if city not in cities:
        cities.append(city)
        
# Print city count to confirm sufficient count
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hofn
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | mendi
# Processing Record 4 of Set 1 | dickinson
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | caravelas
# Processing Record 7 of Set 1 | sayansk
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | saint-pierre
# Processing Record 10 of Set 1 | turiacu
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | gallup
# Processing Record 14 of Set 1 | terrace
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | port hardy
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | garachine
# Processing Record 27 of Set 1 | fitjar
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | leningradskiy
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | san cristobal
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | doctor arroyo
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | aksu
# Processing Record 44 of Set 1 | ancud
# Processing Record 45 of Set 1 | buren
# Processing Record 46 of Set 1 | kapasan
# Processing Record 47 of Set 1 | novyy urengoy
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | saint anthony
# Processing Record 1 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 2 | inirida
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | hokitika
# Processing Record 7 of Set 2 | rocha
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | boralday
# Processing Record 12 of Set 2 | halifax
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | olafsvik
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | dingle
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | shipitsyno
# Processing Record 24 of Set 2 | kudahuvadhoo
# Processing Record 25 of Set 2 | dekar
# Processing Record 26 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 2 | beloha
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | port lincoln
# Processing Record 30 of Set 2 | imbituba
# Processing Record 31 of Set 2 | geraldton
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | narrabri
# Processing Record 34 of Set 2 | severo-yeniseyskiy
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | tilichiki
# Processing Record 37 of Set 2 | posse
# Processing Record 38 of Set 2 | santa rosalia
# Processing Record 39 of Set 2 | challapata
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | chokwe
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | ambon
# Processing Record 44 of Set 2 | san pedro
# Processing Record 45 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | akyab
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | nome
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | kuala terengganu
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | mogadishu
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | sao filipe
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | ganzhou
# Processing Record 11 of Set 3 | balabac
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | sioux lookout
# Processing Record 15 of Set 3 | brigham city
# Processing Record 16 of Set 3 | kushima
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | lavrentiya
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | costa rica
# Processing Record 21 of Set 3 | farafangana
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | kismayo
# Processing Record 24 of Set 3 | egvekinot
# Processing Record 25 of Set 3 | sosva
# Processing Record 26 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 3 | torbay
# Processing Record 28 of Set 3 | belyy yar
# Processing Record 29 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 3 | lagoa
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | pedernales
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | gonaives
# Processing Record 40 of Set 3 | yarega
# Processing Record 41 of Set 3 | jarjis
# City not found. Skipping...
# Processing Record 42 of Set 3 | merrill
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | boa vista
# Processing Record 45 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 46 of Set 3 | chapleau
# Processing Record 47 of Set 3 | chepareria
# Processing Record 48 of Set 3 | roma
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | bafoulabe
# Processing Record 1 of Set 4 | guozhen
# Processing Record 2 of Set 4 | ola
# Processing Record 3 of Set 4 | puerto carreno
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 6 of Set 4 | paamiut
# Processing Record 7 of Set 4 | lata
# Processing Record 8 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | midland
# Processing Record 12 of Set 4 | conde
# Processing Record 13 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | georgiyevka
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | marsh harbour
# Processing Record 18 of Set 4 | samarai
# Processing Record 19 of Set 4 | neuquen
# Processing Record 20 of Set 4 | iqaluit
# Processing Record 21 of Set 4 | sur
# Processing Record 22 of Set 4 | carmen
# Processing Record 23 of Set 4 | shenjiamen
# Processing Record 24 of Set 4 | kazanskaya
# Processing Record 25 of Set 4 | senneterre
# Processing Record 26 of Set 4 | runcorn
# Processing Record 27 of Set 4 | kiunga
# Processing Record 28 of Set 4 | ajaccio
# Processing Record 29 of Set 4 | upernavik
# Processing Record 30 of Set 4 | saint-joseph
# Processing Record 31 of Set 4 | port hedland
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | mariental
# Processing Record 34 of Set 4 | cabra
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | castro
# Processing Record 37 of Set 4 | casas grandes
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | denham springs
# Processing Record 40 of Set 4 | rongcheng
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | alta floresta
# Processing Record 43 of Set 4 | puro
# Processing Record 44 of Set 4 | acarau
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | pangnirtung
# Processing Record 47 of Set 4 | deputatskiy
# Processing Record 48 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 4 | yenotayevka
# Processing Record 50 of Set 4 | ngorongoro
# Processing Record 1 of Set 5 | keshan
# City not found. Skipping...
# Processing Record 2 of Set 5 | hambantota
# Processing Record 3 of Set 5 | canton
# Processing Record 4 of Set 5 | guerrero negro
# Processing Record 5 of Set 5 | maryville
# Processing Record 6 of Set 5 | khani
# Processing Record 7 of Set 5 | vilyuysk
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | te anau
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | muros
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | amparafaravola
# Processing Record 15 of Set 5 | porto murtinho
# Processing Record 16 of Set 5 | koundara
# Processing Record 17 of Set 5 | rio gallegos
# Processing Record 18 of Set 5 | nador
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | tual
# Processing Record 21 of Set 5 | san juan
# Processing Record 22 of Set 5 | soledade
# Processing Record 23 of Set 5 | salinas
# Processing Record 24 of Set 5 | kimbe
# Processing Record 25 of Set 5 | tshikapa
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 5 | flinders
# Processing Record 28 of Set 5 | tiksi
# Processing Record 29 of Set 5 | nyurba
# Processing Record 30 of Set 5 | sakakah
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | brigantine
# Processing Record 33 of Set 5 | iskateley
# Processing Record 34 of Set 5 | poya
# Processing Record 35 of Set 5 | gorontalo
# Processing Record 36 of Set 5 | abha
# Processing Record 37 of Set 5 | doka
# Processing Record 38 of Set 5 | umea
# Processing Record 39 of Set 5 | carutapera
# Processing Record 40 of Set 5 | vila
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | tortoli
# Processing Record 43 of Set 5 | dicabisagan
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | salalah
# Processing Record 46 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | yeniseysk
# Processing Record 49 of Set 5 | reforma
# Processing Record 50 of Set 5 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | naze
# Processing Record 2 of Set 6 | atherton
# Processing Record 3 of Set 6 | omboue
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | asau
# Processing Record 6 of Set 6 | shieli
# Processing Record 7 of Set 6 | kyzyl-suu
# Processing Record 8 of Set 6 | fernley
# Processing Record 9 of Set 6 | mount isa
# Processing Record 10 of Set 6 | tashtyp
# Processing Record 11 of Set 6 | silifke
# Processing Record 12 of Set 6 | torres
# Processing Record 13 of Set 6 | korla
# Processing Record 14 of Set 6 | najran
# Processing Record 15 of Set 6 | batsfjord
# Processing Record 16 of Set 6 | usinsk
# Processing Record 17 of Set 6 | port blair
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | carnarvon
# Processing Record 20 of Set 6 | riyadh
# Processing Record 21 of Set 6 | sibu
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | chiang rai
# Processing Record 24 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 6 | okha
# Processing Record 26 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 6 | kloulklubed
# Processing Record 28 of Set 6 | tobermory
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | gilgit
# Processing Record 31 of Set 6 | tigre
# Processing Record 32 of Set 6 | belen
# Processing Record 33 of Set 6 | dharchula
# Processing Record 34 of Set 6 | yabrud
# Processing Record 35 of Set 6 | quatre cocos
# Processing Record 36 of Set 6 | chifeng
# Processing Record 37 of Set 6 | touros
# Processing Record 38 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 6 | goderich
# Processing Record 40 of Set 6 | half moon bay
# Processing Record 41 of Set 6 | marzuq
# Processing Record 42 of Set 6 | biak
# Processing Record 43 of Set 6 | clyde
# Processing Record 44 of Set 6 | maceio
# Processing Record 45 of Set 6 | thaton
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | ketou
# Processing Record 48 of Set 6 | ciudad bolivar
# Processing Record 49 of Set 6 | kununurra
# Processing Record 50 of Set 6 | cockburn town
# Processing Record 1 of Set 7 | nemuro
# Processing Record 2 of Set 7 | bemidji
# Processing Record 3 of Set 7 | cayenne
# Processing Record 4 of Set 7 | ayame
# Processing Record 5 of Set 7 | doha
# Processing Record 6 of Set 7 | dongsheng
# Processing Record 7 of Set 7 | fortuna
# Processing Record 8 of Set 7 | provideniya
# Processing Record 9 of Set 7 | tessalit
# Processing Record 10 of Set 7 | bereda
# Processing Record 11 of Set 7 | tazovskiy
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | biltine
# Processing Record 14 of Set 7 | copiapo
# Processing Record 15 of Set 7 | port said
# Processing Record 16 of Set 7 | tocopilla
# Processing Record 17 of Set 7 | tiznit
# Processing Record 18 of Set 7 | bermeo
# Processing Record 19 of Set 7 | rawson
# Processing Record 20 of Set 7 | mpulungu
# Processing Record 21 of Set 7 | xingcheng
# Processing Record 22 of Set 7 | dutlwe
# Processing Record 23 of Set 7 | lincoln
# Processing Record 24 of Set 7 | sao joao da barra
# Processing Record 25 of Set 7 | tineo
# Processing Record 26 of Set 7 | yenagoa
# Processing Record 27 of Set 7 | visnes
# Processing Record 28 of Set 7 | fonte boa
# Processing Record 29 of Set 7 | bondowoso
# Processing Record 30 of Set 7 | villamontes
# Processing Record 31 of Set 7 | kavaratti
# Processing Record 32 of Set 7 | kapit
# Processing Record 33 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 7 | rodekro
# Processing Record 35 of Set 7 | jacmel
# Processing Record 36 of Set 7 | whitianga
# Processing Record 37 of Set 7 | westport
# Processing Record 38 of Set 7 | ionia
# Processing Record 39 of Set 7 | inuvik
# Processing Record 40 of Set 7 | kyzyl-mazhalyk
# Processing Record 41 of Set 7 | auki
# Processing Record 42 of Set 7 | hervey bay
# Processing Record 43 of Set 7 | caucaia
# Processing Record 44 of Set 7 | yumen
# Processing Record 45 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 7 | kisesa
# Processing Record 47 of Set 7 | totness
# Processing Record 48 of Set 7 | marawi
# Processing Record 49 of Set 7 | thinadhoo
# Processing Record 50 of Set 7 | katherine
# Processing Record 1 of Set 8 | hadejia
# Processing Record 2 of Set 8 | fort nelson
# Processing Record 3 of Set 8 | beni mazar
# Processing Record 4 of Set 8 | bathsheba
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | araguaina
# Processing Record 7 of Set 8 | bam
# Processing Record 8 of Set 8 | wyndham
# Processing Record 9 of Set 8 | general roca
# Processing Record 10 of Set 8 | manggar
# Processing Record 11 of Set 8 | amahai
# Processing Record 12 of Set 8 | nouadhibou
# Processing Record 13 of Set 8 | taman
# Processing Record 14 of Set 8 | dogondoutchi
# Processing Record 15 of Set 8 | aykhal
# Processing Record 16 of Set 8 | margate
# Processing Record 17 of Set 8 | roald
# Processing Record 18 of Set 8 | kapuskasing
# Processing Record 19 of Set 8 | baijiantan
# Processing Record 20 of Set 8 | dwarka
# Processing Record 21 of Set 8 | krasnoselkup
# Processing Record 22 of Set 8 | ozernovskiy
# Processing Record 23 of Set 8 | mandalgovi
# Processing Record 24 of Set 8 | gao
# Processing Record 25 of Set 8 | mangrol
# Processing Record 26 of Set 8 | umm lajj
# Processing Record 27 of Set 8 | kwekwe
# Processing Record 28 of Set 8 | tuy hoa
# Processing Record 29 of Set 8 | merauke
# Processing Record 30 of Set 8 | jakoruda
# City not found. Skipping...
# Processing Record 31 of Set 8 | berlevag
# Processing Record 32 of Set 8 | tete
# Processing Record 33 of Set 8 | poum
# Processing Record 34 of Set 8 | opuwo
# Processing Record 35 of Set 8 | coihaique
# Processing Record 36 of Set 8 | urazovka
# Processing Record 37 of Set 8 | shangrao
# Processing Record 38 of Set 8 | meulaboh
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | saint-georges
# Processing Record 41 of Set 8 | grand gaube
# Processing Record 42 of Set 8 | thompson
# Processing Record 43 of Set 8 | puerto escondido
# Processing Record 44 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 8 | sao sepe
# Processing Record 46 of Set 8 | urumqi
# Processing Record 47 of Set 8 | norman wells
# Processing Record 48 of Set 8 | pimentel
# Processing Record 49 of Set 8 | digby
# Processing Record 50 of Set 8 | alvarado
# Processing Record 1 of Set 9 | aklavik
# Processing Record 2 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 9 | christchurch
# Processing Record 4 of Set 9 | jiayuguan
# Processing Record 5 of Set 9 | hohhot
# Processing Record 6 of Set 9 | chornukhy
# Processing Record 7 of Set 9 | vladivostok
# Processing Record 8 of Set 9 | parintins
# Processing Record 9 of Set 9 | yeppoon
# Processing Record 10 of Set 9 | winnemucca
# Processing Record 11 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 12 of Set 9 | nebolchi
# Processing Record 13 of Set 9 | artyom
# Processing Record 14 of Set 9 | lalmohan
# Processing Record 15 of Set 9 | sovetskiy
# Processing Record 16 of Set 9 | point pedro
# Processing Record 17 of Set 9 | abdanan
# Processing Record 18 of Set 9 | zhuanghe
# Processing Record 19 of Set 9 | shingu
# Processing Record 20 of Set 9 | toma
# Processing Record 21 of Set 9 | banda aceh
# Processing Record 22 of Set 9 | metro
# Processing Record 23 of Set 9 | quebo
# Processing Record 24 of Set 9 | ahmadpur sial
# Processing Record 25 of Set 9 | kichera
# Processing Record 26 of Set 9 | batagay
# Processing Record 27 of Set 9 | alekseyevskaya
# Processing Record 28 of Set 9 | banjar
# Processing Record 29 of Set 9 | santa cruz
# Processing Record 30 of Set 9 | hutchinson
# Processing Record 31 of Set 9 | zhigansk
# Processing Record 32 of Set 9 | bilibino
# Processing Record 33 of Set 9 | santa isabel do rio negro
# Processing Record 34 of Set 9 | hudiksvall
# Processing Record 35 of Set 9 | porto novo
# Processing Record 36 of Set 9 | mugur-aksy
# Processing Record 37 of Set 9 | mongoumba
# Processing Record 38 of Set 9 | besikduzu
# Processing Record 39 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 9 | verkhnevilyuysk
# Processing Record 41 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 9 | waipawa
# Processing Record 43 of Set 9 | villa maria
# Processing Record 44 of Set 9 | kishi
# Processing Record 45 of Set 9 | kirakira
# Processing Record 46 of Set 9 | pahrump
# Processing Record 47 of Set 9 | benha
# City not found. Skipping...
# Processing Record 48 of Set 9 | killybegs
# Processing Record 49 of Set 9 | cookeville
# Processing Record 50 of Set 9 | byron bay
# Processing Record 1 of Set 10 | iralaya
# Processing Record 2 of Set 10 | mlyniv
# Processing Record 3 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 10 | xinzhou
# Processing Record 5 of Set 10 | saint-augustin
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | portland
# Processing Record 8 of Set 10 | arona
# Processing Record 9 of Set 10 | catamarca
# Processing Record 10 of Set 10 | saint-leu
# Processing Record 11 of Set 10 | bundaberg
# Processing Record 12 of Set 10 | nouakchott
# Processing Record 13 of Set 10 | taywarah
# Processing Record 14 of Set 10 | morro bay
# Processing Record 15 of Set 10 | burns lake
# Processing Record 16 of Set 10 | porbandar
# Processing Record 17 of Set 10 | tokur
# Processing Record 18 of Set 10 | baykit
# Processing Record 19 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | gat
# Processing Record 22 of Set 10 | sao miguel do araguaia
# Processing Record 23 of Set 10 | kiama
# Processing Record 24 of Set 10 | brewster
# Processing Record 25 of Set 10 | patria
# Processing Record 26 of Set 10 | the valley
# Processing Record 27 of Set 10 | youhao
# Processing Record 28 of Set 10 | esperance
# Processing Record 29 of Set 10 | pesqueira
# Processing Record 30 of Set 10 | campbeltown
# Processing Record 31 of Set 10 | jacareacanga
# Processing Record 32 of Set 10 | andenes
# Processing Record 33 of Set 10 | kinkala
# Processing Record 34 of Set 10 | dothan
# Processing Record 35 of Set 10 | wyszkow
# Processing Record 36 of Set 10 | hebertville
# City not found. Skipping...
# Processing Record 37 of Set 10 | matagami
# Processing Record 38 of Set 10 | kyra
# Processing Record 39 of Set 10 | char bhadrasan
# Processing Record 40 of Set 10 | basay
# Processing Record 41 of Set 10 | nikolskoye
# Processing Record 42 of Set 10 | bobo dioulasso
# Processing Record 43 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 10 | adana
# Processing Record 45 of Set 10 | husavik
# Processing Record 46 of Set 10 | eureka
# Processing Record 47 of Set 10 | siguiri
# Processing Record 48 of Set 10 | grindavik
# Processing Record 49 of Set 10 | ji-parana
# City not found. Skipping...
# Processing Record 50 of Set 10 | podgorica
# Processing Record 1 of Set 11 | kulasi
# City not found. Skipping...
# Processing Record 2 of Set 11 | wewak
# Processing Record 3 of Set 11 | acapulco
# Processing Record 4 of Set 11 | bahia blanca
# Processing Record 5 of Set 11 | barcelona
# Processing Record 6 of Set 11 | massakory
# Processing Record 7 of Set 11 | kofele
# Processing Record 8 of Set 11 | sangmelima
# Processing Record 9 of Set 11 | tsogni
# Processing Record 10 of Set 11 | lewisporte
# Processing Record 11 of Set 11 | sire
# Processing Record 12 of Set 11 | namatanai
# Processing Record 13 of Set 11 | sioux falls
# Processing Record 14 of Set 11 | mananara
# Processing Record 15 of Set 11 | grand-lahou
# Processing Record 16 of Set 11 | sindor
# Processing Record 17 of Set 11 | cardston
# Processing Record 18 of Set 11 | itapuranga
# Processing Record 19 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 11 | buala
# Processing Record 21 of Set 11 | kalga
# Processing Record 22 of Set 11 | antalaha
# Processing Record 23 of Set 11 | karasjok
# Processing Record 24 of Set 11 | pareora
# Processing Record 25 of Set 11 | tongzi
# Processing Record 26 of Set 11 | bulungu
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | port-gentil
# Processing Record 29 of Set 11 | alihe
# Processing Record 30 of Set 11 | newport
# Processing Record 31 of Set 11 | turkmenabat
# Processing Record 32 of Set 11 | kaeo
# Processing Record 33 of Set 11 | douentza
# Processing Record 34 of Set 11 | naral
# City not found. Skipping...
# Processing Record 35 of Set 11 | vao
# Processing Record 36 of Set 11 | birao
# Processing Record 37 of Set 11 | tadine
# Processing Record 38 of Set 11 | gimli
# Processing Record 39 of Set 11 | orlik
# Processing Record 40 of Set 11 | gidole
# Processing Record 41 of Set 11 | gander
# Processing Record 42 of Set 11 | bowen
# Processing Record 43 of Set 11 | la sarre
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | sola
# Processing Record 46 of Set 11 | champerico
# Processing Record 47 of Set 11 | la rioja
# Processing Record 48 of Set 11 | koumac
# Processing Record 49 of Set 11 | priargunsk
# Processing Record 50 of Set 11 | coquimbo
# Processing Record 1 of Set 12 | adre
# Processing Record 2 of Set 12 | hashtrud
# Processing Record 3 of Set 12 | kontagora
# Processing Record 4 of Set 12 | port elizabeth
# Processing Record 5 of Set 12 | kuching
# Processing Record 6 of Set 12 | sampit
# Processing Record 7 of Set 12 | east wenatchee bench
# Processing Record 8 of Set 12 | chapais
# Processing Record 9 of Set 12 | ondjiva
# Processing Record 10 of Set 12 | kabugao
# Processing Record 11 of Set 12 | nizwa
# Processing Record 12 of Set 12 | lakes entrance
# Processing Record 13 of Set 12 | ankpa
# Processing Record 14 of Set 12 | pontes e lacerda
# Processing Record 15 of Set 12 | angoche
# Processing Record 16 of Set 12 | sandwick
# Processing Record 17 of Set 12 | nirmal
# Processing Record 18 of Set 12 | alta
# Processing Record 19 of Set 12 | bon air
# Processing Record 20 of Set 12 | suluq
# Processing Record 21 of Set 12 | maniitsoq
# Processing Record 22 of Set 12 | vanimo
# Processing Record 23 of Set 12 | athabasca
# Processing Record 24 of Set 12 | soma
# Processing Record 25 of Set 12 | san quintin
# Processing Record 26 of Set 12 | taltal
# Processing Record 27 of Set 12 | mocuba
# Processing Record 28 of Set 12 | wamba
# Processing Record 29 of Set 12 | cukai
# Processing Record 30 of Set 12 | sao jose da coroa grande
# Processing Record 31 of Set 12 | trelew
# Processing Record 32 of Set 12 | kunming
# Processing Record 33 of Set 12 | karratha
# Processing Record 34 of Set 12 | fort beaufort
# Processing Record 35 of Set 12 | zyryanka
# Processing Record 36 of Set 12 | batagay-alyta
# Processing Record 37 of Set 12 | noyabrsk
# Processing Record 38 of Set 12 | hovd
# Processing Record 39 of Set 12 | jussara
# Processing Record 40 of Set 12 | araguacu
# Processing Record 41 of Set 12 | palauig
# Processing Record 42 of Set 12 | kosa
# Processing Record 43 of Set 12 | khandyga
# Processing Record 44 of Set 12 | dunedin
# Processing Record 45 of Set 12 | ilulissat
# Processing Record 46 of Set 12 | pacific grove
# Processing Record 47 of Set 12 | vaitape
# Processing Record 48 of Set 12 | mulanje
# Processing Record 49 of Set 12 | jakar
# Processing Record 50 of Set 12 | havre-saint-pierre
# Processing Record 1 of Set 13 | cururupu
# Processing Record 2 of Set 13 | terney
# Processing Record 3 of Set 13 | mantua
# Processing Record 4 of Set 13 | ust-kulom
# Processing Record 5 of Set 13 | bonn
# Processing Record 6 of Set 13 | mount pleasant
# Processing Record 7 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 8 of Set 13 | batticaloa
# Processing Record 9 of Set 13 | mitu
# Processing Record 10 of Set 13 | ayan
# Processing Record 11 of Set 13 | bauchi
# Processing Record 12 of Set 13 | buin
# Processing Record 13 of Set 13 | manama
# Processing Record 14 of Set 13 | reconquista
# Processing Record 15 of Set 13 | rumphi
# Processing Record 16 of Set 13 | lyngdal
# Processing Record 17 of Set 13 | veraval
# Processing Record 18 of Set 13 | formosa do rio preto
# Processing Record 19 of Set 13 | ivanava
# Processing Record 20 of Set 13 | mersing
# Processing Record 21 of Set 13 | fukue
# Processing Record 22 of Set 13 | aiquile
# Processing Record 23 of Set 13 | tiarei
# Processing Record 24 of Set 13 | nusaybin
# Processing Record 25 of Set 13 | biri
# Processing Record 26 of Set 13 | ponta delgada
# Processing Record 27 of Set 13 | mount gambier
# Processing Record 28 of Set 13 | sisimiut
# Processing Record 29 of Set 13 | tipitapa
# Processing Record 30 of Set 13 | hansot
# Processing Record 31 of Set 13 | gamba
# Processing Record 32 of Set 13 | hobyo
# Processing Record 33 of Set 13 | saint-francois
# Processing Record 34 of Set 13 | stornoway
# Processing Record 35 of Set 13 | nuuk
# Processing Record 36 of Set 13 | kavieng
# Processing Record 37 of Set 13 | hami
# Processing Record 38 of Set 13 | san patricio
# Processing Record 39 of Set 13 | salta
# Processing Record 40 of Set 13 | huancavelica
# Processing Record 41 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 13 | kalmunai
# Processing Record 43 of Set 13 | macaubas
# Processing Record 44 of Set 13 | baykalsk
# Processing Record 45 of Set 13 | mairang
# Processing Record 46 of Set 13 | altay
# Processing Record 47 of Set 13 | remedios
# Processing Record 48 of Set 13 | marfino
# Processing Record 49 of Set 13 | riohacha
# Processing Record 50 of Set 13 | ust-karsk
# Processing Record 1 of Set 14 | lowestoft
# Processing Record 2 of Set 14 | tornio
# Processing Record 3 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 14 | campbell river
# Processing Record 5 of Set 14 | tromso
# Processing Record 6 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 14 | hatillo
# Processing Record 8 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 14 | itarema
# Processing Record 10 of Set 14 | moron
# Processing Record 11 of Set 14 | vila franca do campo
# Processing Record 12 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 14 | talavera de la reina
# Processing Record 14 of Set 14 | whitehorse
# Processing Record 15 of Set 14 | stromness
# Processing Record 16 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 14 | vysokogornyy
# Processing Record 18 of Set 14 | lazaro cardenas
# Processing Record 19 of Set 14 | etchoropo
# Processing Record 20 of Set 14 | brae
# Processing Record 21 of Set 14 | gusau
# Processing Record 22 of Set 14 | phnum penh
# City not found. Skipping...
# Processing Record 23 of Set 14 | sri aman
# Processing Record 24 of Set 14 | houma
# Processing Record 25 of Set 14 | presidencia roque saenz pena
# Processing Record 26 of Set 14 | vilcun
# Processing Record 27 of Set 14 | yar-sale
# Processing Record 28 of Set 14 | la suiza
# Processing Record 29 of Set 14 | erzin
# Processing Record 30 of Set 14 | camacha
# Processing Record 31 of Set 14 | kamarai
# Processing Record 32 of Set 14 | pacifica
# Processing Record 33 of Set 14 | vostok
# Processing Record 34 of Set 14 | narsaq
# Processing Record 35 of Set 14 | podbelsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | troitskoye
# Processing Record 37 of Set 14 | fare
# Processing Record 38 of Set 14 | the pas
# Processing Record 39 of Set 14 | magadan
# Processing Record 40 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | safford
# Processing Record 44 of Set 14 | roanoke rapids
# Processing Record 45 of Set 14 | sechura
# Processing Record 46 of Set 14 | kota bahru
# Processing Record 47 of Set 14 | yefimovskiy
# City not found. Skipping...
# Processing Record 48 of Set 14 | mayumba
# Processing Record 49 of Set 14 | makakilo city
# Processing Record 50 of Set 14 | malanville
# Processing Record 1 of Set 15 | kudat
# Processing Record 2 of Set 15 | nazare
# Processing Record 3 of Set 15 | ust-ilimsk
# Processing Record 4 of Set 15 | nantucket
# Processing Record 5 of Set 15 | fuling
# Processing Record 6 of Set 15 | fallon
# Processing Record 7 of Set 15 | kruisfontein
# Processing Record 8 of Set 15 | constantine
# Processing Record 9 of Set 15 | santarem
# Processing Record 10 of Set 15 | adrar
# Processing Record 11 of Set 15 | turinsk
# Processing Record 12 of Set 15 | gizo
# Processing Record 13 of Set 15 | keroka
# Processing Record 14 of Set 15 | ostrovnoy
# Processing Record 15 of Set 15 | ipinda
# Processing Record 16 of Set 15 | kurayoshi
# Processing Record 17 of Set 15 | waingapu
# Processing Record 18 of Set 15 | kondagaon
# Processing Record 19 of Set 15 | laguna
# Processing Record 20 of Set 15 | dovolnoye
# Processing Record 21 of Set 15 | xacmaz
# Processing Record 22 of Set 15 | narasannapeta
# Processing Record 23 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 24 of Set 15 | pechora
# Processing Record 25 of Set 15 | marrakesh
# Processing Record 26 of Set 15 | arapongas
# Processing Record 27 of Set 15 | council bluffs
# Processing Record 28 of Set 15 | kortkeros
# Processing Record 29 of Set 15 | san vicente
# Processing Record 30 of Set 15 | bonfim
# Processing Record 31 of Set 15 | bako
# Processing Record 32 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 15 | troitsk
# Processing Record 34 of Set 15 | marabba
# Processing Record 35 of Set 15 | fenoarivo
# Processing Record 36 of Set 15 | florianopolis
# Processing Record 37 of Set 15 | qaqortoq
# Processing Record 38 of Set 15 | changde
# Processing Record 39 of Set 15 | noumea
# Processing Record 40 of Set 15 | lengyeltoti
# Processing Record 41 of Set 15 | mount vernon
# Processing Record 42 of Set 15 | ventanas
# Processing Record 43 of Set 15 | oktyabrskoye
# Processing Record 44 of Set 15 | jimenez
# Processing Record 45 of Set 15 | nosy varika
# Processing Record 46 of Set 15 | vikramasingapuram
# Processing Record 47 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 48 of Set 15 | mareeba
# Processing Record 49 of Set 15 | bridgetown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hofn      IS  64.2539  -15.2082     46.08       100         100
# 1       Qaanaaq      GL  77.4840  -69.3632      0.25        62           0
# 2         Mendi      PG  -6.1761  143.6513     61.12        94          96
# 3     Dickinson      US  29.4608  -95.0513     77.95        87          20
# 4        Dikson      RU  73.5069   80.5464     12.90        89          95
# 5     Caravelas      BR -17.7125  -39.2481     72.90        87          97
# 6       Sayansk      RU  54.1088  102.1648     43.11        70          66
# 7       Rikitea      PF -23.1203 -134.9692     74.17        85           7
# 8  Saint-Pierre      RE -21.3393   55.4781     83.57        75           0
# 9       Turiacu      BR  -1.6633  -45.3717     74.97        95          99
#
#    Wind Speed Current Description
# 0        0.92     overcast clouds
# 1        8.30           clear sky
# 2        2.53          light rain
# 3        3.00          few clouds
# 4       18.68     overcast clouds
# 5        5.91     overcast clouds
# 6       11.50       broken clouds
# 7       20.18           clear sky
# 8        4.61           clear sky
# 9        3.62     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
