# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Create list for holding the cities
cities = []

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city is unique, add to cities list
    if city not in cities:
        cities.append(city)
        
# Print city count to confirm sufficient count
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | todos santos
# Processing Record 2 of Set 1 | marawi
# Processing Record 3 of Set 1 | berdigestyakh
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ulladulla
# Processing Record 6 of Set 1 | casa nova
# Processing Record 7 of Set 1 | luanda
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | rudsar
# Processing Record 10 of Set 1 | floro
# Processing Record 11 of Set 1 | fasa
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | tautira
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | nelson bay
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | pitimbu
# Processing Record 21 of Set 1 | maldonado
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | boa vista
# Processing Record 26 of Set 1 | sakaiminato
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | faya
# Processing Record 29 of Set 1 | yashkino
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | sao miguel do araguaia
# Processing Record 33 of Set 1 | sinnamary
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | norsup
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | poum
# Processing Record 39 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 1 | xadani
# City not found. Skipping...
# Processing Record 41 of Set 1 | acajutla
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | dondo
# Processing Record 45 of Set 1 | ewa beach
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | kurilsk
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | agadez
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 4 of Set 2 | hakodate
# Processing Record 5 of Set 2 | kochi
# Processing Record 6 of Set 2 | probolinggo
# Processing Record 7 of Set 2 | phrai bung
# City not found. Skipping...
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | hukuntsi
# Processing Record 10 of Set 2 | sur
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | sharjah
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | tabou
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | yar-sale
# Processing Record 23 of Set 2 | hinton
# Processing Record 24 of Set 2 | hervey bay
# Processing Record 25 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | plettenberg bay
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | mareeba
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | sorong
# Processing Record 33 of Set 2 | renqiu
# Processing Record 34 of Set 2 | bridlington
# Processing Record 35 of Set 2 | cuitareo
# Processing Record 36 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 2 | tabas
# Processing Record 38 of Set 2 | belaya gora
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | homer
# Processing Record 41 of Set 2 | garissa
# Processing Record 42 of Set 2 | tambun
# Processing Record 43 of Set 2 | ishigaki
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | maniitsoq
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | impfondo
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 3 | bubaque
# Processing Record 8 of Set 3 | port blair
# Processing Record 9 of Set 3 | gimbi
# Processing Record 10 of Set 3 | wiwili
# Processing Record 11 of Set 3 | omvriaki
# Processing Record 12 of Set 3 | burdur
# Processing Record 13 of Set 3 | hovd
# Processing Record 14 of Set 3 | maceio
# Processing Record 15 of Set 3 | muros
# Processing Record 16 of Set 3 | vila franca do campo
# Processing Record 17 of Set 3 | umm kaddadah
# Processing Record 18 of Set 3 | port moresby
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | fernandez
# Processing Record 21 of Set 3 | avera
# Processing Record 22 of Set 3 | chagoda
# Processing Record 23 of Set 3 | barda
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | borovskoy
# Processing Record 26 of Set 3 | miguel auza
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 3 | ushuaia
# Processing Record 30 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | ullal
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | tongliao
# Processing Record 36 of Set 3 | aloleng
# Processing Record 37 of Set 3 | kalmunai
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | tuktoyaktuk
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | bakloh
# Processing Record 44 of Set 3 | dakar
# Processing Record 45 of Set 3 | havoysund
# Processing Record 46 of Set 3 | suntar
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | paita
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | campbell river
# Processing Record 2 of Set 4 | mana
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 5 of Set 4 | bojnurd
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | daru
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | chambas
# Processing Record 13 of Set 4 | keflavik
# Processing Record 14 of Set 4 | mahebourg
# Processing Record 15 of Set 4 | sakakah
# Processing Record 16 of Set 4 | mashhad
# Processing Record 17 of Set 4 | zyryanka
# Processing Record 18 of Set 4 | diamantino
# Processing Record 19 of Set 4 | bandarbeyla
# Processing Record 20 of Set 4 | basoko
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | imbituba
# Processing Record 23 of Set 4 | letterkenny
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | antalaha
# Processing Record 26 of Set 4 | opuwo
# Processing Record 27 of Set 4 | benguela
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | dorgos
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | bonito
# Processing Record 33 of Set 4 | banda aceh
# Processing Record 34 of Set 4 | rovaniemi
# Processing Record 35 of Set 4 | gander
# Processing Record 36 of Set 4 | lazaro cardenas
# Processing Record 37 of Set 4 | juba
# Processing Record 38 of Set 4 | armilla
# Processing Record 39 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 40 of Set 4 | valparaiso
# Processing Record 41 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 4 | ipixuna
# Processing Record 44 of Set 4 | soller
# Processing Record 45 of Set 4 | pevek
# Processing Record 46 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 4 | ifanadiana
# Processing Record 48 of Set 4 | kriel
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 50 of Set 4 | koumac
# Processing Record 1 of Set 5 | dauphin
# Processing Record 2 of Set 5 | mahon
# Processing Record 3 of Set 5 | carnduff
# Processing Record 4 of Set 5 | mansa
# Processing Record 5 of Set 5 | nevel
# Processing Record 6 of Set 5 | cairns
# Processing Record 7 of Set 5 | te anau
# Processing Record 8 of Set 5 | derazhnya
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | beringovskiy
# Processing Record 12 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 13 of Set 5 | djibo
# Processing Record 14 of Set 5 | asfi
# Processing Record 15 of Set 5 | college
# Processing Record 16 of Set 5 | moron
# Processing Record 17 of Set 5 | paka
# Processing Record 18 of Set 5 | maskinonge
# Processing Record 19 of Set 5 | iratosu
# Processing Record 20 of Set 5 | burghausen
# Processing Record 21 of Set 5 | hay river
# Processing Record 22 of Set 5 | san quintin
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | mountain home
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | kolokani
# Processing Record 27 of Set 5 | lasa
# Processing Record 28 of Set 5 | gamba
# Processing Record 29 of Set 5 | kieta
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | rio grande
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | rio bananal
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | murud
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | vestmanna
# Processing Record 38 of Set 5 | grand gaube
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | hede
# Processing Record 41 of Set 5 | amapa
# Processing Record 42 of Set 5 | sola
# Processing Record 43 of Set 5 | jalu
# Processing Record 44 of Set 5 | burgeo
# Processing Record 45 of Set 5 | zhenjiang
# Processing Record 46 of Set 5 | alappuzha
# Processing Record 47 of Set 5 | soma
# Processing Record 48 of Set 5 | kuusamo
# Processing Record 49 of Set 5 | smolenka
# Processing Record 50 of Set 5 | torbay
# Processing Record 1 of Set 6 | pacific grove
# Processing Record 2 of Set 6 | the valley
# Processing Record 3 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 6 | kaeo
# Processing Record 7 of Set 6 | kungurtug
# Processing Record 8 of Set 6 | ossora
# Processing Record 9 of Set 6 | atar
# Processing Record 10 of Set 6 | krasnaya gorbatka
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | bethel
# Processing Record 13 of Set 6 | saint anthony
# Processing Record 14 of Set 6 | djambala
# Processing Record 15 of Set 6 | bonfim
# Processing Record 16 of Set 6 | konza
# Processing Record 17 of Set 6 | camopi
# Processing Record 18 of Set 6 | luganville
# Processing Record 19 of Set 6 | tezu
# Processing Record 20 of Set 6 | maltahohe
# Processing Record 21 of Set 6 | iwanai
# Processing Record 22 of Set 6 | fuerte olimpo
# Processing Record 23 of Set 6 | bagdarin
# Processing Record 24 of Set 6 | verkhovyna
# Processing Record 25 of Set 6 | suraabad
# Processing Record 26 of Set 6 | videira
# Processing Record 27 of Set 6 | san felipe
# Processing Record 28 of Set 6 | marand
# Processing Record 29 of Set 6 | bulgan
# Processing Record 30 of Set 6 | bloomington
# Processing Record 31 of Set 6 | kuching
# Processing Record 32 of Set 6 | kodinsk
# Processing Record 33 of Set 6 | fairbanks
# Processing Record 34 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 6 | chifeng
# Processing Record 36 of Set 6 | acarau
# Processing Record 37 of Set 6 | saldanha
# Processing Record 38 of Set 6 | erzin
# Processing Record 39 of Set 6 | neubrandenburg
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | aksu
# Processing Record 42 of Set 6 | yumen
# Processing Record 43 of Set 6 | sulangan
# Processing Record 44 of Set 6 | magpet
# Processing Record 45 of Set 6 | minyar
# Processing Record 46 of Set 6 | lesnoy
# Processing Record 47 of Set 6 | cabo san lucas
# Processing Record 48 of Set 6 | talaya
# Processing Record 49 of Set 6 | tiquisate
# Processing Record 50 of Set 6 | rawson
# Processing Record 1 of Set 7 | xai-xai
# Processing Record 2 of Set 7 | taveta
# Processing Record 3 of Set 7 | victoria
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | aden
# Processing Record 6 of Set 7 | sri aman
# Processing Record 7 of Set 7 | barra do pirai
# Processing Record 8 of Set 7 | teplodar
# Processing Record 9 of Set 7 | esperance
# Processing Record 10 of Set 7 | praia da vitoria
# Processing Record 11 of Set 7 | majene
# Processing Record 12 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | sao joao da barra
# Processing Record 15 of Set 7 | vavuniya
# Processing Record 16 of Set 7 | mayumba
# Processing Record 17 of Set 7 | port hedland
# Processing Record 18 of Set 7 | port lincoln
# Processing Record 19 of Set 7 | kavieng
# Processing Record 20 of Set 7 | port shepstone
# Processing Record 21 of Set 7 | iranduba
# Processing Record 22 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 7 | meulaboh
# Processing Record 24 of Set 7 | komatipoort
# Processing Record 25 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 26 of Set 7 | salalah
# Processing Record 27 of Set 7 | casma
# Processing Record 28 of Set 7 | ugoofaaru
# Processing Record 29 of Set 7 | bontang
# Processing Record 30 of Set 7 | saint stephen
# Processing Record 31 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 7 | pitkyaranta
# Processing Record 33 of Set 7 | verkhnyaya inta
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | puerto del rosario
# Processing Record 36 of Set 7 | ayna
# Processing Record 37 of Set 7 | salto
# Processing Record 38 of Set 7 | ginda
# Processing Record 39 of Set 7 | quatre cocos
# Processing Record 40 of Set 7 | mauguio
# Processing Record 41 of Set 7 | erenhot
# Processing Record 42 of Set 7 | faanui
# Processing Record 43 of Set 7 | alihe
# Processing Record 44 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 7 | fulacunda
# City not found. Skipping...
# Processing Record 46 of Set 7 | mkushi
# Processing Record 47 of Set 7 | ponte de sor
# Processing Record 48 of Set 7 | vostok
# Processing Record 49 of Set 7 | olafsvik
# Processing Record 50 of Set 7 | port augusta
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | barcelos
# Processing Record 3 of Set 8 | acapulco
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | malkara
# Processing Record 6 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 7 of Set 8 | makubetsu
# Processing Record 8 of Set 8 | dunedin
# Processing Record 9 of Set 8 | bilisht
# Processing Record 10 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 8 | zonguldak
# Processing Record 12 of Set 8 | winnemucca
# Processing Record 13 of Set 8 | lerwick
# Processing Record 14 of Set 8 | malanje
# Processing Record 15 of Set 8 | boden
# Processing Record 16 of Set 8 | mongar
# Processing Record 17 of Set 8 | udachnyy
# Processing Record 18 of Set 8 | powell river
# Processing Record 19 of Set 8 | mount isa
# Processing Record 20 of Set 8 | merritt island
# Processing Record 21 of Set 8 | new ulm
# Processing Record 22 of Set 8 | nantucket
# Processing Record 23 of Set 8 | kloulklubed
# Processing Record 24 of Set 8 | nadym
# Processing Record 25 of Set 8 | bardsir
# Processing Record 26 of Set 8 | villa maria
# Processing Record 27 of Set 8 | damghan
# Processing Record 28 of Set 8 | arlit
# Processing Record 29 of Set 8 | cidreira
# Processing Record 30 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 8 | evanston
# Processing Record 32 of Set 8 | hlotse
# Processing Record 33 of Set 8 | kalabo
# Processing Record 34 of Set 8 | naze
# Processing Record 35 of Set 8 | constantine
# Processing Record 36 of Set 8 | zambezi
# Processing Record 37 of Set 8 | kamina
# Processing Record 38 of Set 8 | baruun-urt
# Processing Record 39 of Set 8 | lewistown
# Processing Record 40 of Set 8 | cingoli
# Processing Record 41 of Set 8 | hambantota
# Processing Record 42 of Set 8 | mazatlan
# Processing Record 43 of Set 8 | panacan
# Processing Record 44 of Set 8 | lavrentiya
# Processing Record 45 of Set 8 | jiangyou
# Processing Record 46 of Set 8 | yining
# Processing Record 47 of Set 8 | beyneu
# Processing Record 48 of Set 8 | trat
# Processing Record 49 of Set 8 | santa cruz
# Processing Record 50 of Set 8 | las margaritas
# Processing Record 1 of Set 9 | morgan city
# Processing Record 2 of Set 9 | makinsk
# Processing Record 3 of Set 9 | plon
# Processing Record 4 of Set 9 | tieli
# Processing Record 5 of Set 9 | znamenskoye
# Processing Record 6 of Set 9 | polson
# Processing Record 7 of Set 9 | ngatea
# Processing Record 8 of Set 9 | young
# Processing Record 9 of Set 9 | hamilton
# Processing Record 10 of Set 9 | constitucion
# Processing Record 11 of Set 9 | pocone
# Processing Record 12 of Set 9 | gushikawa
# Processing Record 13 of Set 9 | bathsheba
# Processing Record 14 of Set 9 | kabelvag
# Processing Record 15 of Set 9 | coihueco
# Processing Record 16 of Set 9 | aklera
# Processing Record 17 of Set 9 | medina del campo
# Processing Record 18 of Set 9 | kutum
# Processing Record 19 of Set 9 | salinopolis
# Processing Record 20 of Set 9 | najran
# Processing Record 21 of Set 9 | zhanaozen
# Processing Record 22 of Set 9 | roma
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | morges
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | bonavista
# Processing Record 27 of Set 9 | pangkalanbuun
# Processing Record 28 of Set 9 | ak-dovurak
# Processing Record 29 of Set 9 | narrabri
# Processing Record 30 of Set 9 | krasnoselkup
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 9 | seymchan
# Processing Record 34 of Set 9 | bilibino
# Processing Record 35 of Set 9 | tiksi
# Processing Record 36 of Set 9 | shahrud
# Processing Record 37 of Set 9 | coihaique
# Processing Record 38 of Set 9 | paoua
# Processing Record 39 of Set 9 | puerto leguizamo
# Processing Record 40 of Set 9 | nicoya
# Processing Record 41 of Set 9 | onokhoy
# Processing Record 42 of Set 9 | sosnytsya
# Processing Record 43 of Set 9 | ahipara
# Processing Record 44 of Set 9 | alice springs
# Processing Record 45 of Set 9 | troitsko-pechorsk
# Processing Record 46 of Set 9 | lagoa
# Processing Record 47 of Set 9 | boromo
# Processing Record 48 of Set 9 | nome
# Processing Record 49 of Set 9 | ponta delgada
# Processing Record 50 of Set 9 | thinadhoo
# Processing Record 1 of Set 10 | nouadhibou
# Processing Record 2 of Set 10 | paamiut
# Processing Record 3 of Set 10 | maiduguri
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | comodoro rivadavia
# Processing Record 6 of Set 10 | amga
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | mecca
# Processing Record 9 of Set 10 | xihe
# Processing Record 10 of Set 10 | flinders
# Processing Record 11 of Set 10 | tianpeng
# Processing Record 12 of Set 10 | mugur-aksy
# Processing Record 13 of Set 10 | ovsyanka
# Processing Record 14 of Set 10 | khudumelapye
# Processing Record 15 of Set 10 | oktyabrskiy
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | hokitika
# Processing Record 18 of Set 10 | scarborough
# Processing Record 19 of Set 10 | kingman
# Processing Record 20 of Set 10 | madera
# Processing Record 21 of Set 10 | tonantins
# Processing Record 22 of Set 10 | qaqortoq
# Processing Record 23 of Set 10 | yeppoon
# Processing Record 24 of Set 10 | dicabisagan
# Processing Record 25 of Set 10 | jibuti
# Processing Record 26 of Set 10 | sao jose da coroa grande
# Processing Record 27 of Set 10 | otofuke
# Processing Record 28 of Set 10 | ixtacuixtla
# City not found. Skipping...
# Processing Record 29 of Set 10 | dinguiraye
# Processing Record 30 of Set 10 | hasaki
# Processing Record 31 of Set 10 | geraldton
# Processing Record 32 of Set 10 | kautokeino
# Processing Record 33 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 10 | leh
# Processing Record 35 of Set 10 | batagay
# Processing Record 36 of Set 10 | vetlanda
# Processing Record 37 of Set 10 | ketchikan
# Processing Record 38 of Set 10 | cap malheureux
# Processing Record 39 of Set 10 | seydi
# Processing Record 40 of Set 10 | mzimba
# Processing Record 41 of Set 10 | asyut
# Processing Record 42 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 10 | soloneshnoye
# Processing Record 44 of Set 10 | amuntai
# Processing Record 45 of Set 10 | alta floresta
# Processing Record 46 of Set 10 | pokhara
# Processing Record 47 of Set 10 | husavik
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | ajaccio
# Processing Record 50 of Set 10 | pisco
# Processing Record 1 of Set 11 | kaduy
# Processing Record 2 of Set 11 | dubbo
# Processing Record 3 of Set 11 | teya
# Processing Record 4 of Set 11 | las vegas
# Processing Record 5 of Set 11 | harper
# Processing Record 6 of Set 11 | ouadda
# Processing Record 7 of Set 11 | yaviza
# Processing Record 8 of Set 11 | cuijk
# Processing Record 9 of Set 11 | kaffrine
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 11 | tessalit
# Processing Record 13 of Set 11 | kota bahru
# Processing Record 14 of Set 11 | wenling
# Processing Record 15 of Set 11 | kathu
# Processing Record 16 of Set 11 | khash
# Processing Record 17 of Set 11 | doba
# Processing Record 18 of Set 11 | tuatapere
# Processing Record 19 of Set 11 | lorengau
# Processing Record 20 of Set 11 | hachinohe
# Processing Record 21 of Set 11 | vanavara
# Processing Record 22 of Set 11 | rhyl
# Processing Record 23 of Set 11 | lucapa
# Processing Record 24 of Set 11 | datong
# Processing Record 25 of Set 11 | buraydah
# Processing Record 26 of Set 11 | dolores
# Processing Record 27 of Set 11 | marzuq
# Processing Record 28 of Set 11 | stornoway
# Processing Record 29 of Set 11 | santiago
# Processing Record 30 of Set 11 | deputatskiy
# Processing Record 31 of Set 11 | kwinana
# Processing Record 32 of Set 11 | council bluffs
# Processing Record 33 of Set 11 | srandakan
# Processing Record 34 of Set 11 | sao felix do xingu
# Processing Record 35 of Set 11 | waingapu
# Processing Record 36 of Set 11 | darhan
# Processing Record 37 of Set 11 | ambilobe
# Processing Record 38 of Set 11 | namibe
# Processing Record 39 of Set 11 | cherbourg
# Processing Record 40 of Set 11 | baleshwar
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | ardabil
# Processing Record 43 of Set 11 | shahr-e babak
# Processing Record 44 of Set 11 | nizhnyaya tura
# Processing Record 45 of Set 11 | kamenka
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | shunyi
# Processing Record 48 of Set 11 | kosh-agach
# Processing Record 49 of Set 11 | brigantine
# Processing Record 50 of Set 11 | brae
# Processing Record 1 of Set 12 | uaua
# Processing Record 2 of Set 12 | saint-denis
# Processing Record 3 of Set 12 | catalao
# Processing Record 4 of Set 12 | sarangani
# Processing Record 5 of Set 12 | verkhnevilyuysk
# Processing Record 6 of Set 12 | zhangjiakou
# Processing Record 7 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 12 | chabahar
# Processing Record 9 of Set 12 | kenai
# Processing Record 10 of Set 12 | hofn
# Processing Record 11 of Set 12 | wiarton
# Processing Record 12 of Set 12 | bilozerka
# Processing Record 13 of Set 12 | vao
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | sarahan
# Processing Record 16 of Set 12 | leirvik
# Processing Record 17 of Set 12 | carballo
# Processing Record 18 of Set 12 | lata
# Processing Record 19 of Set 12 | cabedelo
# Processing Record 20 of Set 12 | tarakan
# Processing Record 21 of Set 12 | akyab
# Processing Record 22 of Set 12 | taltal
# Processing Record 23 of Set 12 | anshun
# Processing Record 24 of Set 12 | sao felipe
# Processing Record 25 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 26 of Set 12 | ostrovnoy
# Processing Record 27 of Set 12 | pelotas
# Processing Record 28 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 12 | talnakh
# Processing Record 30 of Set 12 | kununurra
# Processing Record 31 of Set 12 | barpeta
# Processing Record 32 of Set 12 | russell
# Processing Record 33 of Set 12 | wattegama
# Processing Record 34 of Set 12 | ulaanbaatar
# Processing Record 35 of Set 12 | zaranj
# Processing Record 36 of Set 12 | santa rosalia
# Processing Record 37 of Set 12 | karasjok
# Processing Record 38 of Set 12 | halifax
# Processing Record 39 of Set 12 | mandera
# Processing Record 40 of Set 12 | fare
# Processing Record 41 of Set 12 | gao
# Processing Record 42 of Set 12 | tongren
# Processing Record 43 of Set 12 | flin flon
# Processing Record 44 of Set 12 | horta
# Processing Record 45 of Set 12 | hualmay
# Processing Record 46 of Set 12 | alyangula
# Processing Record 47 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 12 | pailon
# Processing Record 49 of Set 12 | katobu
# Processing Record 50 of Set 12 | shingu
# Processing Record 1 of Set 13 | raga
# Processing Record 2 of Set 13 | madikeri
# Processing Record 3 of Set 13 | teknaf
# Processing Record 4 of Set 13 | iracoubo
# Processing Record 5 of Set 13 | batasan
# Processing Record 6 of Set 13 | asekeyevo
# Processing Record 7 of Set 13 | guane
# Processing Record 8 of Set 13 | komsomolskiy
# Processing Record 9 of Set 13 | campina verde
# Processing Record 10 of Set 13 | bhakkar
# Processing Record 11 of Set 13 | santa clara
# Processing Record 12 of Set 13 | camacha
# Processing Record 13 of Set 13 | dungarpur
# Processing Record 14 of Set 13 | ancud
# Processing Record 15 of Set 13 | nhulunbuy
# Processing Record 16 of Set 13 | airai
# Processing Record 17 of Set 13 | maxixe
# Processing Record 18 of Set 13 | ylivieska
# Processing Record 19 of Set 13 | odate
# Processing Record 20 of Set 13 | placerville
# Processing Record 21 of Set 13 | samarai
# Processing Record 22 of Set 13 | yaring
# Processing Record 23 of Set 13 | vigeland
# Processing Record 24 of Set 13 | havelock
# Processing Record 25 of Set 13 | uyskoye
# Processing Record 26 of Set 13 | sturgeon falls
# Processing Record 27 of Set 13 | nokaneng
# Processing Record 28 of Set 13 | chiang klang
# Processing Record 29 of Set 13 | viedma
# Processing Record 30 of Set 13 | necochea
# Processing Record 31 of Set 13 | omsukchan
# Processing Record 32 of Set 13 | bonwapitse
# Processing Record 33 of Set 13 | hays
# Processing Record 34 of Set 13 | bima
# Processing Record 35 of Set 13 | los llanos de aridane
# Processing Record 36 of Set 13 | ust-nera
# Processing Record 37 of Set 13 | chernaya kholunitsa
# Processing Record 38 of Set 13 | karaton
# Processing Record 39 of Set 13 | ust-ishim
# Processing Record 40 of Set 13 | tukrah
# Processing Record 41 of Set 13 | ngunguru
# Processing Record 42 of Set 13 | alekseyevsk
# Processing Record 43 of Set 13 | kupino
# Processing Record 44 of Set 13 | santa isabel do rio negro
# Processing Record 45 of Set 13 | glendive
# Processing Record 46 of Set 13 | severnoye
# Processing Record 47 of Set 13 | yaan
# Processing Record 48 of Set 13 | jinzhou
# Processing Record 49 of Set 13 | kumo
# Processing Record 50 of Set 13 | siilinjarvi
# Processing Record 1 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 2 of Set 14 | tete
# Processing Record 3 of Set 14 | poya
# Processing Record 4 of Set 14 | kapit
# Processing Record 5 of Set 14 | sambava
# Processing Record 6 of Set 14 | raudeberg
# Processing Record 7 of Set 14 | barreirinha
# Processing Record 8 of Set 14 | alofi
# Processing Record 9 of Set 14 | torrington
# Processing Record 10 of Set 14 | abu dhabi
# Processing Record 11 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 14 | muzhi
# Processing Record 13 of Set 14 | burica
# City not found. Skipping...
# Processing Record 14 of Set 14 | acari
# Processing Record 15 of Set 14 | labytnangi
# Processing Record 16 of Set 14 | palmer
# Processing Record 17 of Set 14 | broken hill
# Processing Record 18 of Set 14 | qui nhon
# Processing Record 19 of Set 14 | tilichiki
# Processing Record 20 of Set 14 | teguise
# Processing Record 21 of Set 14 | prince george
# Processing Record 22 of Set 14 | mogadishu
# Processing Record 23 of Set 14 | berea
# Processing Record 24 of Set 14 | yongzhou
# Processing Record 25 of Set 14 | san isidro
# Processing Record 26 of Set 14 | aktau
# Processing Record 27 of Set 14 | eloy
# Processing Record 28 of Set 14 | boyolangu
# Processing Record 29 of Set 14 | ambon
# Processing Record 30 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 31 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 32 of Set 14 | rio grande city
# Processing Record 33 of Set 14 | anchorage
# Processing Record 34 of Set 14 | canutama
# Processing Record 35 of Set 14 | singleton
# Processing Record 36 of Set 14 | presidencia roque saenz pena
# Processing Record 37 of Set 14 | hendijan
# City not found. Skipping...
# Processing Record 38 of Set 14 | ampanihy
# Processing Record 39 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 40 of Set 14 | ghanzi
# Processing Record 41 of Set 14 | kyzyl-suu
# Processing Record 42 of Set 14 | yarega
# Processing Record 43 of Set 14 | hagenow
# Processing Record 44 of Set 14 | shaowu
# Processing Record 45 of Set 14 | boke
# Processing Record 46 of Set 14 | nalut
# Processing Record 47 of Set 14 | namwala
# Processing Record 48 of Set 14 | salmas
# Processing Record 49 of Set 14 | vetluga
# Processing Record 50 of Set 14 | port macquarie
# Processing Record 1 of Set 15 | la libertad
# Processing Record 2 of Set 15 | biak
# Processing Record 3 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 15 | adwa
# Processing Record 5 of Set 15 | fuengirola
# Processing Record 6 of Set 15 | tura
# Processing Record 7 of Set 15 | zaraza
# Processing Record 8 of Set 15 | aswan
# Processing Record 9 of Set 15 | seoul
# Processing Record 10 of Set 15 | gobabis
# Processing Record 11 of Set 15 | chernyshevskiy
# Processing Record 12 of Set 15 | wanxian
# Processing Record 13 of Set 15 | krasnyy kut
# Processing Record 14 of Set 15 | mirandopolis
# Processing Record 15 of Set 15 | taoudenni
# Processing Record 16 of Set 15 | namatanai
# Processing Record 17 of Set 15 | samfya
# Processing Record 18 of Set 15 | prieska
# Processing Record 19 of Set 15 | mount gambier
# Processing Record 20 of Set 15 | pemangkat
# Processing Record 21 of Set 15 | hudson bay
# Processing Record 22 of Set 15 | loudeac
# Processing Record 23 of Set 15 | bossangoa
# Processing Record 24 of Set 15 | carutapera
# Processing Record 25 of Set 15 | uruzgan
# Processing Record 26 of Set 15 | trairi
# Processing Record 27 of Set 15 | royan
# Processing Record 28 of Set 15 | miri
# Processing Record 29 of Set 15 | khorinsk
# Processing Record 30 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 15 | nurobod
# Processing Record 32 of Set 15 | bakal
# Processing Record 33 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 15 | saint-pierre
# Processing Record 35 of Set 15 | jales
# Processing Record 36 of Set 15 | arecibo
# Processing Record 37 of Set 15 | risch
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Todos Santos      MX  23.4500 -110.2167     78.01        84          19
# 1         Marawi      PH   7.9986  124.2928     74.64        88         100
# 2  Berdigestyakh      RU  62.0989  126.6992     35.08        86         100
# 3          Bluff      NZ -46.6000  168.3333     54.50        77          98
# 4      Ulladulla      AU -35.3500  150.4667     82.76        58          51
# 5      Casa Nova      BR  -9.4167  -41.1333     76.98        66          97
# 6         Luanda      AO  -8.8368   13.2343     76.62        80          93
# 7        Rikitea      PF -23.1203 -134.9692     74.01        85           2
# 8         Rudsar      IR  37.1376   50.2880     62.65        61           0
# 9          Floro      NO  61.5996    5.0328     40.96        81          20
#
#    Wind Speed Current Description
# 0        6.31          few clouds
# 1        4.70          light rain
# 2       11.77     overcast clouds
# 3       13.11     overcast clouds
# 4        9.60       broken clouds
# 5       10.51     overcast clouds
# 6        6.73     overcast clouds
# 7       20.31           clear sky
# 8        1.50           clear sky
# 9        9.22          few clouds

# %%
# Create the output file (CSV)
output_data_file = "C:/Users/betti/Desktop/World_weather_analysis/Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
